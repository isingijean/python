# %%
import os
file ='l7.txt'
if os.path.exists(file):
    os.remove(file)
    print('your file has deleted')
else:
    print('File does not exists')
# Out:
# File does not exists

# %%
file ='remove'
if os.path.exists(file):
    os.rmdir('remove')
    print('your folder has deleted')
else:
    print('Folder does not exists')
# Out:
# your folder has deleted

# %%
import numpy 
arr = numpy.array([1,2,3,4,5])
# mean
print(arr.mean())
print(arr.std())
print(numpy.sqrt(arr))
print(numpy.exp(arr))
# Out:
# 3.0
# 1.4142135623730951
# [1.         1.41421356 1.73205081 2.         2.23606798]
# [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]

# %%
# Matplot
import matplotlib.pyplot as plt

# input
x = [1,2,3,4,5,6]
y = [40,50,60,70,80,90]

plt.plot(x,y, marker='o', label = 'Data')
plt.xlabel('time')
plt.ylabel('results')
plt.title('Time Management')
plt.legend()
plt.show()
